# %% [markdown]
# # Statistical Power - Lab
#
# ## Introduction
#
#
# In this lesson, you'll practice doing a power-analysis during experimental design. As you've seen, power analysis allows you to determine the sample size required to detect an effect of a given size with a given degree of confidence. In other words, it allows you to determine the probability of detecting an effect of a given size with a given level of confidence, under-sample size constraints.
#
# The following four factors have an intimate relationship:
#
# * Sample size
# * Effect size
# * Significance level = P (Type I error) = probability of finding an effect that is not there
# * **Power = 1 - P (Type II error)** = probability of finding an effect that is there
#
# Given any three of these, we can easily determine the fourth.
#
# ## Objectives
#
# You will be able to:
#
# * Describe the concept of “Power” in relation to p-value and effect size for hypothesis testing
# * Understand and critically evaluate the factors influencing the power of an experiment
# * Perform Power calculation using SciPy and Python
# * Demonstrate the impact of sample size on statistical power using simulations
# * Demonstrate the combined effect of sample size and effect size on statistical power using simulations
#
# ## Let's get started!
#
# To start, let's import the necessary libraries required for this simulation:.

# %%
import numpy as np
import scipy.stats as stats
import pandas
import matplotlib.pyplot as plt

# %% [markdown]
# ## Scenario
#
# A researcher wants to study how daily protein supplementation in the elderly population will affect baseline liver fat. The study budget will allow enrollment of 24 patients. Half will be randomized to a placebo group and half to the protein supplement treatment group and the trial will be carried out over one month. It is desired to see whether the mean change in percentage of liver fat from baseline to the end of the study differs between the two groups in the study.
#
# With this, the researcher writes the null hypothesis:
#
#     There is no difference between experimental and control means i.e. H0 is equal to H1
#
# And the alternative Hypothesis:
#
#     There is a difference between experimental and control means i.e. H0 is not equal to H1
#
# The researcher needs to know what power  will be obtained under the sample size restrictions to identify a change in mean percent liver fat of 0.17. Based on past results, a common standard deviation of 0.21 will be used for each treatment group in the power analysis.
#
# To determine the practicality of this experimental design, you'll a power analysis simulation.

# %%
# Number of patients in each group
sample_size = 12

# Control group
control_mean = 0
control_sd = 0.21

# Experimental group
experimental_mean = 0.17
experimental_sd = 0.21

#Set the number of simulations for our test = 1000
n_sim = 1000

# %% [markdown]
# You can now start running our simulations to run an independent t-test with above data and store the calculated p_value in our `p` array. Perform following tasks.
#
# * Initialize a numpy array and fill it with Nan values for storing the results (p_value) of the independent T-test.
# * For a defined number of simulations (i.e. 1000), do the following:
#
#     * Generate a random normal variable with control mean and sd
#     * Generate a random normal variable with experimental mean and sd
#     * Run and independent t-test using control and experimental data
#     * Store the p value for each test
#
# * Calculate the total number and overall proportion of simulations and where Null hypothesis is rejected

# %%
# For reproducibility 

np.random.seed(10)

# Initialize array to store results
p = (np.empty(n_sim))
p.fill(np.nan)

#  Run a for loop for range of values in n_sim
for s in range(n_sim):
    control = np.random.normal(loc=control_mean, scale=control_sd, size=sample_size)
    experimental = np.random.normal(loc=experimental_mean, scale=experimental_sd, size=sample_size)
    t_test = stats.ttest_ind(control, experimental)
    p[s] = t_test[1]
# number of null hypothesis rejections
num_null_rejects = np.sum(p < 0.05)
power = num_null_rejects/float(n_sim)

power

# 0.495
# Out:
# 0.495

# %% [markdown]
# These results indicate that using 12 participants in each group and with given statistics, the statistical power of the experiment is 49%. This can be interpreted as follows:
#
# > **If a large effect (.17 or greater) is truly present between control and experimental groups, then the null hypothesis (i.e. no difference with alpha 0.05) would be rejected 49% of the time. **

# %% [markdown]
# ## Sample size requirements for a given effect size
#
# Often in behavioral research .8 is accepted as a sufficient level of power.
#
# Clearly, this is not the case for the experiment as currently designed. Determine the required sample size in order to identify a difference of .17 or greater between the group means with an 80% power.

# %%
# required power 0.95
from statsmodels.stats.power import TTestPower
power = TTestPower()
sample_size = power.solve_power(effect_size=.17, alpha=0.05, power=.8)
sample_size
target = 0.8

# %%
# minimum sample size to start the simulations 
sample_size = 12
num_null_rejected = 0
n_sim = 10000

# %% [markdown]
# As above, perform the following
#
# * Initialize an empty array for storing results
# * initialize a list for storing sample size x power summary
# * While current power is less than the target power
#     * Generate distributions for control and experimental groups using given statistics (as before)
#     * Run a t-test and store results
#     * Calculate current power
#     * Output current sample size and power calculated for inspection
#     * Store results: Sample size, power
#     * increase the sample size by 1 and repeat

# %%
np.random.seed(10)

p = (np.empty(n_sim))
p.fill(np.nan)

power_sample = []
while num_null_rejected < target:
    data = np.empty([n_sim, sample_size, 2])
    data.fill(np.nan)

# keep iterating as shown above until desired power is obtained
# For control group 
# Here we specify size=[n_sim, sample_size] which creates an array of n_sim number of arrays,
# each containing sample_size number of elements. 
# This is equivalent to manually looping n_sim times like we did above but is much faster.
    data[:,:,0] = np.random.normal(loc=control_mean, scale=control_sd, size=[n_sim, sample_size])
# For experimental group
    data[:,:,1] = np.random.normal(loc=experimental_mean, scale=experimental_sd, size=[n_sim, sample_size])            
    
    result = stats.ttest_ind(data[:, :, 0],data[:, :, 1],axis=1)
                                
    p_vals = result[1] 
#Since you know that all simulations are from a different distribution \
    #all those that rejected the null-hypothesis are valid
    null_rejected = np.sum(p_vals < 0.05) / n_sim

    print("Number of Samples:", sample_size,", Calculated Power =", null_rejected)
    power_sample.append([sample_size, null_rejected])

    # increase the number of samples by one for the next iteration of the loop
    sample_size += 1
# Out:
# Number of Samples: 12 , Calculated Power = 0.4754
# Number of Samples: 13 , Calculated Power = 0.5066
# Number of Samples: 14 , Calculated Power = 0.5423
# Number of Samples: 15 , Calculated Power = 0.5767
# Number of Samples: 16 , Calculated Power = 0.6038
# Number of Samples: 17 , Calculated Power = 0.6297
# Number of Samples: 18 , Calculated Power = 0.658
# Number of Samples: 19 , Calculated Power = 0.6783
# Number of Samples: 20 , Calculated Power = 0.7056
# Number of Samples: 21 , Calculated Power = 0.7266
# Number of Samples: 22 , Calculated Power = 0.7481
# Number of Samples: 23 , Calculated Power = 0.7624
# Number of Samples: 24 , Calculated Power = 0.7864
# Number of Samples: 25 , Calculated Power = 0.8031
# Number of Samples: 26 , Calculated Power = 0.8178
# Number of Samples: 27 , Calculated Power = 0.8354
# Number of Samples: 28 , Calculated Power = 0.8405
# Number of Samples: 29 , Calculated Power = 0.8568
# Number of Samples: 30 , Calculated Power = 0.8736
# Number of Samples: 31 , Calculated Power = 0.8786
# Number of Samples: 32 , Calculated Power = 0.89
# Number of Samples: 33 , Calculated Power = 0.8975
# Number of Samples: 34 , Calculated Power = 0.9077
# Number of Samples: 35 , Calculated Power = 0.9146
# Number of Samples: 36 , Calculated Power = 0.9188
# Number of Samples: 37 , Calculated Power = 0.9292
# Number of Samples: 38 , Calculated Power = 0.9369
# Number of Samples: 39 , Calculated Power = 0.9369
# Number of Samples: 40 , Calculated Power = 0.9482
# Number of Samples: 41 , Calculated Power = 0.9521
# Number of Samples: 42 , Calculated Power = 0.9589
# Number of Samples: 43 , Calculated Power = 0.9622
# Number of Samples: 44 , Calculated Power = 0.9623
# Number of Samples: 45 , Calculated Power = 0.968
# Number of Samples: 46 , Calculated Power = 0.9706
# Number of Samples: 47 , Calculated Power = 0.9722
# Number of Samples: 48 , Calculated Power = 0.9767
# Number of Samples: 49 , Calculated Power = 0.9774
# Number of Samples: 50 , Calculated Power = 0.9784
# Number of Samples: 51 , Calculated Power = 0.9845
# Number of Samples: 52 , Calculated Power = 0.9855
# Number of Samples: 53 , Calculated Power = 0.9869
# Number of Samples: 54 , Calculated Power = 0.988
# Number of Samples: 55 , Calculated Power = 0.9892
# Number of Samples: 56 , Calculated Power = 0.9896
# Number of Samples: 57 , Calculated Power = 0.9898
# Number of Samples: 58 , Calculated Power = 0.9914
# Number of Samples: 59 , Calculated Power = 0.992
# Number of Samples: 60 , Calculated Power = 0.9919
# Number of Samples: 61 , Calculated Power = 0.9936
# Number of Samples: 62 , Calculated Power = 0.9935
# Number of Samples: 63 , Calculated Power = 0.9954
# Number of Samples: 64 , Calculated Power = 0.9952
# Number of Samples: 65 , Calculated Power = 0.9956
# Number of Samples: 66 , Calculated Power = 0.9977
# Number of Samples: 67 , Calculated Power = 0.9977
# Number of Samples: 68 , Calculated Power = 0.9965
# Number of Samples: 69 , Calculated Power = 0.9974
# Number of Samples: 70 , Calculated Power = 0.9982
# Number of Samples: 71 , Calculated Power = 0.9985
# Number of Samples: 72 , Calculated Power = 0.9979
# Number of Samples: 73 , Calculated Power = 0.9981
# Number of Samples: 74 , Calculated Power = 0.9989
# Number of Samples: 75 , Calculated Power = 0.9991
# Number of Samples: 76 , Calculated Power = 0.9982
# Number of Samples: 77 , Calculated Power = 0.9985
# Number of Samples: 78 , Calculated Power = 0.9994
# Number of Samples: 79 , Calculated Power = 0.9992
# Number of Samples: 80 , Calculated Power = 0.9992
# Number of Samples: 81 , Calculated Power = 0.9994
# Number of Samples: 82 , Calculated Power = 0.9993
# Number of Samples: 83 , Calculated Power = 0.9996
# Number of Samples: 84 , Calculated Power = 0.9994
# Number of Samples: 85 , Calculated Power = 0.9999
# Number of Samples: 86 , Calculated Power = 0.9996
# Number of Samples: 87 , Calculated Power = 0.9996
# Number of Samples: 88 , Calculated Power = 0.9999
# Number of Samples: 89 , Calculated Power = 0.9999
# Number of Samples: 90 , Calculated Power = 0.9996
# Number of Samples: 91 , Calculated Power = 0.9999
# Number of Samples: 92 , Calculated Power = 0.9996
# Number of Samples: 93 , Calculated Power = 0.9997
# Number of Samples: 94 , Calculated Power = 0.9998
# Number of Samples: 95 , Calculated Power = 0.9998
# Number of Samples: 96 , Calculated Power = 0.9996
# Number of Samples: 97 , Calculated Power = 0.9999
# Number of Samples: 98 , Calculated Power = 1.0
# Number of Samples: 99 , Calculated Power = 0.9999
# Number of Samples: 100 , Calculated Power = 0.9998
# Number of Samples: 101 , Calculated Power = 1.0
# Number of Samples: 102 , Calculated Power = 0.9999
# Number of Samples: 103 , Calculated Power = 1.0
# Number of Samples: 104 , Calculated Power = 0.9998
# Number of Samples: 105 , Calculated Power = 1.0
# Number of Samples: 106 , Calculated Power = 0.9999
# Number of Samples: 107 , Calculated Power = 1.0
# Number of Samples: 108 , Calculated Power = 0.9998
# Number of Samples: 109 , Calculated Power = 1.0
# Number of Samples: 110 , Calculated Power = 1.0
# Number of Samples: 111 , Calculated Power = 1.0
# Number of Samples: 112 , Calculated Power = 1.0
# Number of Samples: 113 , Calculated Power = 1.0
# Number of Samples: 114 , Calculated Power = 1.0
# Number of Samples: 115 , Calculated Power = 1.0
# Number of Samples: 116 , Calculated Power = 1.0
# Number of Samples: 117 , Calculated Power = 1.0
# Number of Samples: 118 , Calculated Power = 1.0
# Number of Samples: 119 , Calculated Power = 1.0
# Number of Samples: 120 , Calculated Power = 1.0
# Number of Samples: 121 , Calculated Power = 1.0
# Number of Samples: 122 , Calculated Power = 0.9999
# Number of Samples: 123 , Calculated Power = 1.0
# Number of Samples: 124 , Calculated Power = 1.0
# Number of Samples: 125 , Calculated Power = 1.0
# Number of Samples: 126 , Calculated Power = 1.0
# Number of Samples: 127 , Calculated Power = 1.0
# Number of Samples: 128 , Calculated Power = 1.0
# Number of Samples: 129 , Calculated Power = 1.0
# Number of Samples: 130 , Calculated Power = 1.0
# Number of Samples: 131 , Calculated Power = 1.0
# Number of Samples: 132 , Calculated Power = 1.0
# Number of Samples: 133 , Calculated Power = 1.0
# Number of Samples: 134 , Calculated Power = 1.0
# Number of Samples: 135 , Calculated Power = 1.0
# Number of Samples: 136 , Calculated Power = 1.0
# Number of Samples: 137 , Calculated Power = 1.0
# Number of Samples: 138 , Calculated Power = 1.0
# Number of Samples: 139 , Calculated Power = 1.0
# Number of Samples: 140 , Calculated Power = 1.0
# Number of Samples: 141 , Calculated Power = 1.0
# Number of Samples: 142 , Calculated Power = 1.0
# Number of Samples: 143 , Calculated Power = 1.0
# Number of Samples: 144 , Calculated Power = 1.0
# Number of Samples: 145 , Calculated Power = 1.0
# Number of Samples: 146 , Calculated Power = 1.0
# Number of Samples: 147 , Calculated Power = 1.0
# Number of Samples: 148 , Calculated Power = 1.0
# Number of Samples: 149 , Calculated Power = 1.0
# Number of Samples: 150 , Calculated Power = 1.0
# Number of Samples: 151 , Calculated Power = 1.0
# Number of Samples: 152 , Calculated Power = 1.0
# Number of Samples: 153 , Calculated Power = 1.0
# Number of Samples: 154 , Calculated Power = 1.0
# Number of Samples: 155 , Calculated Power = 1.0
# Number of Samples: 156 , Calculated Power = 1.0
# Number of Samples: 157 , Calculated Power = 1.0
# Number of Samples: 158 , Calculated Power = 1.0
# Number of Samples: 159 , Calculated Power = 1.0
# Number of Samples: 160 , Calculated Power = 1.0
# Number of Samples: 161 , Calculated Power = 1.0
# Number of Samples: 162 , Calculated Power = 1.0
# Number of Samples: 163 , Calculated Power = 1.0
# Number of Samples: 164 , Calculated Power = 1.0
# Number of Samples: 165 , Calculated Power = 1.0
# Number of Samples: 166 , Calculated Power = 1.0
# Number of Samples: 167 , Calculated Power = 1.0
# Number of Samples: 168 , Calculated Power = 1.0
# Number of Samples: 169 , Calculated Power = 1.0
# Number of Samples: 170 , Calculated Power = 1.0
# Number of Samples: 171 , Calculated Power = 1.0
# Number of Samples: 172 , Calculated Power = 1.0
# Number of Samples: 173 , Calculated Power = 1.0
# Number of Samples: 174 , Calculated Power = 1.0
# Number of Samples: 175 , Calculated Power = 1.0
# Number of Samples: 176 , Calculated Power = 1.0
# Number of Samples: 177 , Calculated Power = 1.0
# Number of Samples: 178 , Calculated Power = 1.0
# Number of Samples: 179 , Calculated Power = 1.0
# Number of Samples: 180 , Calculated Power = 1.0
# Number of Samples: 181 , Calculated Power = 1.0
# Number of Samples: 182 , Calculated Power = 1.0
# Number of Samples: 183 , Calculated Power = 1.0
# Number of Samples: 184 , Calculated Power = 1.0
# Number of Samples: 185 , Calculated Power = 1.0
# Number of Samples: 186 , Calculated Power = 1.0
# Number of Samples: 187 , Calculated Power = 1.0
# Number of Samples: 188 , Calculated Power = 1.0
# Number of Samples: 189 , Calculated Power = 1.0
# Number of Samples: 190 , Calculated Power = 1.0
# Number of Samples: 191 , Calculated Power = 1.0
# Number of Samples: 192 , Calculated Power = 1.0
# Number of Samples: 193 , Calculated Power = 1.0
# Number of Samples: 194 , Calculated Power = 1.0
# Number of Samples: 195 , Calculated Power = 1.0
# Number of Samples: 196 , Calculated Power = 1.0
# Number of Samples: 197 , Calculated Power = 1.0
# Number of Samples: 198 , Calculated Power = 1.0
# Number of Samples: 199 , Calculated Power = 1.0
# Number of Samples: 200 , Calculated Power = 1.0
# Number of Samples: 201 , Calculated Power = 1.0
# Number of Samples: 202 , Calculated Power = 1.0
# Number of Samples: 203 , Calculated Power = 1.0
# Number of Samples: 204 , Calculated Power = 1.0
# Number of Samples: 205 , Calculated Power = 1.0
# Number of Samples: 206 , Calculated Power = 1.0
# Number of Samples: 207 , Calculated Power = 1.0
# Number of Samples: 208 , Calculated Power = 1.0
# Number of Samples: 209 , Calculated Power = 1.0
# Number of Samples: 210 , Calculated Power = 1.0
# Number of Samples: 211 , Calculated Power = 1.0
# Number of Samples: 212 , Calculated Power = 1.0
# Number of Samples: 213 , Calculated Power = 1.0
# Number of Samples: 214 , Calculated Power = 1.0
# Number of Samples: 215 , Calculated Power = 1.0
# Number of Samples: 216 , Calculated Power = 1.0
# Number of Samples: 217 , Calculated Power = 1.0
# Number of Samples: 218 , Calculated Power = 1.0
# Number of Samples: 219 , Calculated Power = 1.0
# Number of Samples: 220 , Calculated Power = 1.0
# Number of Samples: 221 , Calculated Power = 1.0
# Number of Samples: 222 , Calculated Power = 1.0
# Number of Samples: 223 , Calculated Power = 1.0
# Number of Samples: 224 , Calculated Power = 1.0
# Number of Samples: 225 , Calculated Power = 1.0
# Number of Samples: 226 , Calculated Power = 1.0
# Number of Samples: 227 , Calculated Power = 1.0
# Number of Samples: 228 , Calculated Power = 1.0
# Number of Samples: 229 , Calculated Power = 1.0
# Number of Samples: 230 , Calculated Power = 1.0
# Number of Samples: 231 , Calculated Power = 1.0
# Number of Samples: 232 , Calculated Power = 1.0
# Number of Samples: 233 , Calculated Power = 1.0
# Number of Samples: 234 , Calculated Power = 1.0
# Number of Samples: 235 , Calculated Power = 1.0
# Number of Samples: 236 , Calculated Power = 1.0
# Number of Samples: 237 , Calculated Power = 1.0
# Number of Samples: 238 , Calculated Power = 1.0
# Number of Samples: 239 , Calculated Power = 1.0
# Number of Samples: 240 , Calculated Power = 1.0
# Number of Samples: 241 , Calculated Power = 1.0
# Number of Samples: 242 , Calculated Power = 1.0
# Number of Samples: 243 , Calculated Power = 1.0
# Number of Samples: 244 , Calculated Power = 1.0
# Number of Samples: 245 , Calculated Power = 1.0
# Number of Samples: 246 , Calculated Power = 1.0
# Number of Samples: 247 , Calculated Power = 1.0
# Number of Samples: 248 , Calculated Power = 1.0
# Number of Samples: 249 , Calculated Power = 1.0
# Number of Samples: 250 , Calculated Power = 1.0
# Number of Samples: 251 , Calculated Power = 1.0
# Number of Samples: 252 , Calculated Power = 1.0
# Number of Samples: 253 , Calculated Power = 1.0
# Number of Samples: 254 , Calculated Power = 1.0
# Number of Samples: 255 , Calculated Power = 1.0
# Number of Samples: 256 , Calculated Power = 1.0
# Number of Samples: 257 , Calculated Power = 1.0
# Number of Samples: 258 , Calculated Power = 1.0
# Number of Samples: 259 , Calculated Power = 1.0
# Number of Samples: 260 , Calculated Power = 1.0
# Number of Samples: 261 , Calculated Power = 1.0
# Number of Samples: 262 , Calculated Power = 1.0
# Number of Samples: 263 , Calculated Power = 1.0
# Number of Samples: 264 , Calculated Power = 1.0
# Number of Samples: 265 , Calculated Power = 1.0
# Number of Samples: 266 , Calculated Power = 1.0
# Number of Samples: 267 , Calculated Power = 1.0
# Number of Samples: 268 , Calculated Power = 1.0
# Number of Samples: 269 , Calculated Power = 1.0
# Number of Samples: 270 , Calculated Power = 1.0
# Number of Samples: 271 , Calculated Power = 1.0
# Number of Samples: 272 , Calculated Power = 1.0
# Number of Samples: 273 , Calculated Power = 1.0
# Number of Samples: 274 , Calculated Power = 1.0
# Number of Samples: 275 , Calculated Power = 1.0
# Number of Samples: 276 , Calculated Power = 1.0
# Number of Samples: 277 , Calculated Power = 1.0
# Number of Samples: 278 , Calculated Power = 1.0
# Number of Samples: 279 , Calculated Power = 1.0
# Number of Samples: 280 , Calculated Power = 1.0
# Number of Samples: 281 , Calculated Power = 1.0
# Number of Samples: 282 , Calculated Power = 1.0
# Number of Samples: 283 , Calculated Power = 1.0
# Number of Samples: 284 , Calculated Power = 1.0
# Number of Samples: 285 , Calculated Power = 1.0
# Number of Samples: 286 , Calculated Power = 1.0
# Number of Samples: 287 , Calculated Power = 1.0
# Number of Samples: 288 , Calculated Power = 1.0
# Number of Samples: 289 , Calculated Power = 1.0
# Number of Samples: 290 , Calculated Power = 1.0
# Number of Samples: 291 , Calculated Power = 1.0
# Number of Samples: 292 , Calculated Power = 1.0
# Number of Samples: 293 , Calculated Power = 1.0
# Number of Samples: 294 , Calculated Power = 1.0
# Number of Samples: 295 , Calculated Power = 1.0
# Number of Samples: 296 , Calculated Power = 1.0
# Number of Samples: 297 , Calculated Power = 1.0
# Number of Samples: 298 , Calculated Power = 1.0
# Number of Samples: 299 , Calculated Power = 1.0
# Number of Samples: 300 , Calculated Power = 1.0
# Number of Samples: 301 , Calculated Power = 1.0
# Number of Samples: 302 , Calculated Power = 1.0
# Number of Samples: 303 , Calculated Power = 1.0
# Number of Samples: 304 , Calculated Power = 1.0
# Number of Samples: 305 , Calculated Power = 1.0
# Number of Samples: 306 , Calculated Power = 1.0
# Number of Samples: 307 , Calculated Power = 1.0
# Number of Samples: 308 , Calculated Power = 1.0
# Number of Samples: 309 , Calculated Power = 1.0
# Number of Samples: 310 , Calculated Power = 1.0
# Number of Samples: 311 , Calculated Power = 1.0
# Number of Samples: 312 , Calculated Power = 1.0
# Number of Samples: 313 , Calculated Power = 1.0
# Number of Samples: 314 , Calculated Power = 1.0
# Number of Samples: 315 , Calculated Power = 1.0
# Number of Samples: 316 , Calculated Power = 1.0
# Number of Samples: 317 , Calculated Power = 1.0
# Number of Samples: 318 , Calculated Power = 1.0
# Number of Samples: 319 , Calculated Power = 1.0
# Number of Samples: 320 , Calculated Power = 1.0
# Number of Samples: 321 , Calculated Power = 1.0
# Number of Samples: 322 , Calculated Power = 1.0
# Number of Samples: 323 , Calculated Power = 1.0
# Number of Samples: 324 , Calculated Power = 1.0
# Number of Samples: 325 , Calculated Power = 1.0
# Number of Samples: 326 , Calculated Power = 1.0
# Number of Samples: 327 , Calculated Power = 1.0
# Number of Samples: 328 , Calculated Power = 1.0
# Number of Samples: 329 , Calculated Power = 1.0
# Number of Samples: 330 , Calculated Power = 1.0
# Number of Samples: 331 , Calculated Power = 1.0
# Number of Samples: 332 , Calculated Power = 1.0
# Number of Samples: 333 , Calculated Power = 1.0
# Number of Samples: 334 , Calculated Power = 1.0
# Number of Samples: 335 , Calculated Power = 1.0
# Number of Samples: 336 , Calculated Power = 1.0
# Number of Samples: 337 , Calculated Power = 1.0
# Number of Samples: 338 , Calculated Power = 1.0
# Number of Samples: 339 , Calculated Power = 1.0
# Number of Samples: 340 , Calculated Power = 1.0
# Number of Samples: 341 , Calculated Power = 1.0
# Number of Samples: 342 , Calculated Power = 1.0
# Number of Samples: 343 , Calculated Power = 1.0
# Number of Samples: 344 , Calculated Power = 1.0
# Number of Samples: 345 , Calculated Power = 1.0
# Number of Samples: 346 , Calculated Power = 1.0
# Number of Samples: 347 , Calculated Power = 1.0
# Number of Samples: 348 , Calculated Power = 1.0
# Number of Samples: 349 , Calculated Power = 1.0
# Number of Samples: 350 , Calculated Power = 1.0
# Number of Samples: 351 , Calculated Power = 1.0
# Number of Samples: 352 , Calculated Power = 1.0
# Number of Samples: 353 , Calculated Power = 1.0
# Number of Samples: 354 , Calculated Power = 1.0
# Number of Samples: 355 , Calculated Power = 1.0
# Number of Samples: 356 , Calculated Power = 1.0
# Number of Samples: 357 , Calculated Power = 1.0
# Number of Samples: 358 , Calculated Power = 1.0
# Number of Samples: 359 , Calculated Power = 1.0
# Number of Samples: 360 , Calculated Power = 1.0
# Number of Samples: 361 , Calculated Power = 1.0
# Number of Samples: 362 , Calculated Power = 1.0
# Number of Samples: 363 , Calculated Power = 1.0
# Number of Samples: 364 , Calculated Power = 1.0
# Number of Samples: 365 , Calculated Power = 1.0
# Number of Samples: 366 , Calculated Power = 1.0
# Number of Samples: 367 , Calculated Power = 1.0
# Number of Samples: 368 , Calculated Power = 1.0
# Number of Samples: 369 , Calculated Power = 1.0
# Number of Samples: 370 , Calculated Power = 1.0
# Number of Samples: 371 , Calculated Power = 1.0
# Number of Samples: 372 , Calculated Power = 1.0
# Number of Samples: 373 , Calculated Power = 1.0
# Number of Samples: 374 , Calculated Power = 1.0
# Number of Samples: 375 , Calculated Power = 1.0
# Number of Samples: 376 , Calculated Power = 1.0
# Number of Samples: 377 , Calculated Power = 1.0
# Number of Samples: 378 , Calculated Power = 1.0
# Number of Samples: 379 , Calculated Power = 1.0
# Number of Samples: 380 , Calculated Power = 1.0
# Number of Samples: 381 , Calculated Power = 1.0
# Number of Samples: 382 , Calculated Power = 1.0
# Number of Samples: 383 , Calculated Power = 1.0
# Number of Samples: 384 , Calculated Power = 1.0
# Number of Samples: 385 , Calculated Power = 1.0
# Number of Samples: 386 , Calculated Power = 1.0
# Number of Samples: 387 , Calculated Power = 1.0
# Number of Samples: 388 , Calculated Power = 1.0
# Number of Samples: 389 , Calculated Power = 1.0
# Number of Samples: 390 , Calculated Power = 1.0
# Number of Samples: 391 , Calculated Power = 1.0
# Number of Samples: 392 , Calculated Power = 1.0
# Number of Samples: 393 , Calculated Power = 1.0
# Number of Samples: 394 , Calculated Power = 1.0
# Number of Samples: 395 , Calculated Power = 1.0
# Number of Samples: 396 , Calculated Power = 1.0
# Number of Samples: 397 , Calculated Power = 1.0
# Number of Samples: 398 , Calculated Power = 1.0
# Number of Samples: 399 , Calculated Power = 1.0
# Number of Samples: 400 , Calculated Power = 1.0
# Number of Samples: 401 , Calculated Power = 1.0
# Number of Samples: 402 , Calculated Power = 1.0
# Number of Samples: 403 , Calculated Power = 1.0
# Number of Samples: 404 , Calculated Power = 1.0
# Number of Samples: 405 , Calculated Power = 1.0
# Number of Samples: 406 , Calculated Power = 1.0
# Number of Samples: 407 , Calculated Power = 1.0
# Number of Samples: 408 , Calculated Power = 1.0
# Number of Samples: 409 , Calculated Power = 1.0
# Number of Samples: 410 , Calculated Power = 1.0
# Number of Samples: 411 , Calculated Power = 1.0
# Number of Samples: 412 , Calculated Power = 1.0
# Number of Samples: 413 , Calculated Power = 1.0
# Number of Samples: 414 , Calculated Power = 1.0
# Number of Samples: 415 , Calculated Power = 1.0
# Number of Samples: 416 , Calculated Power = 1.0
# Number of Samples: 417 , Calculated Power = 1.0
# Number of Samples: 418 , Calculated Power = 1.0
# Number of Samples: 419 , Calculated Power = 1.0
# Number of Samples: 420 , Calculated Power = 1.0
# Number of Samples: 421 , Calculated Power = 1.0
# Number of Samples: 422 , Calculated Power = 1.0
# Number of Samples: 423 , Calculated Power = 1.0
# Number of Samples: 424 , Calculated Power = 1.0
# Number of Samples: 425 , Calculated Power = 1.0
# Number of Samples: 426 , Calculated Power = 1.0
# Number of Samples: 427 , Calculated Power = 1.0
# Number of Samples: 428 , Calculated Power = 1.0
# Number of Samples: 429 , Calculated Power = 1.0
# Number of Samples: 430 , Calculated Power = 1.0
# Number of Samples: 431 , Calculated Power = 1.0
# Number of Samples: 432 , Calculated Power = 1.0
# Number of Samples: 433 , Calculated Power = 1.0
# Number of Samples: 434 , Calculated Power = 1.0
# Number of Samples: 435 , Calculated Power = 1.0
# Number of Samples: 436 , Calculated Power = 1.0
# Number of Samples: 437 , Calculated Power = 1.0
# Number of Samples: 438 , Calculated Power = 1.0
# Number of Samples: 439 , Calculated Power = 1.0
# Number of Samples: 440 , Calculated Power = 1.0
# Number of Samples: 441 , Calculated Power = 1.0
# Number of Samples: 442 , Calculated Power = 1.0
# Number of Samples: 443 , Calculated Power = 1.0
# Number of Samples: 444 , Calculated Power = 1.0
# Number of Samples: 445 , Calculated Power = 1.0
# Number of Samples: 446 , Calculated Power = 1.0
# Number of Samples: 447 , Calculated Power = 1.0
# Number of Samples: 448 , Calculated Power = 1.0
# Number of Samples: 449 , Calculated Power = 1.0
# Number of Samples: 450 , Calculated Power = 1.0
# Number of Samples: 451 , Calculated Power = 1.0
# Number of Samples: 452 , Calculated Power = 1.0
# Number of Samples: 453 , Calculated Power = 1.0
# Number of Samples: 454 , Calculated Power = 1.0
# Number of Samples: 455 , Calculated Power = 1.0
# Number of Samples: 456 , Calculated Power = 1.0
# Number of Samples: 457 , Calculated Power = 1.0
# Number of Samples: 458 , Calculated Power = 1.0
# Number of Samples: 459 , Calculated Power = 1.0
# Number of Samples: 460 , Calculated Power = 1.0
# Number of Samples: 461 , Calculated Power = 1.0
# Number of Samples: 462 , Calculated Power = 1.0
# Number of Samples: 463 , Calculated Power = 1.0
# Number of Samples: 464 , Calculated Power = 1.0
# Number of Samples: 465 , Calculated Power = 1.0
# Number of Samples: 466 , Calculated Power = 1.0
# Number of Samples: 467 , Calculated Power = 1.0
# Number of Samples: 468 , Calculated Power = 1.0
# Number of Samples: 469 , Calculated Power = 1.0
# Number of Samples: 470 , Calculated Power = 1.0
# Number of Samples: 471 , Calculated Power = 1.0
# Number of Samples: 472 , Calculated Power = 1.0
# Number of Samples: 473 , Calculated Power = 1.0
# Number of Samples: 474 , Calculated Power = 1.0
# Number of Samples: 475 , Calculated Power = 1.0
# Number of Samples: 476 , Calculated Power = 1.0
# Number of Samples: 477 , Calculated Power = 1.0
# Number of Samples: 478 , Calculated Power = 1.0
# Number of Samples: 479 , Calculated Power = 1.0
# Number of Samples: 480 , Calculated Power = 1.0
# Number of Samples: 481 , Calculated Power = 1.0
# Number of Samples: 482 , Calculated Power = 1.0
# Number of Samples: 483 , Calculated Power = 1.0
# Number of Samples: 484 , Calculated Power = 1.0
# Number of Samples: 485 , Calculated Power = 1.0
# Number of Samples: 486 , Calculated Power = 1.0
# Number of Samples: 487 , Calculated Power = 1.0
# Number of Samples: 488 , Calculated Power = 1.0
# Number of Samples: 489 , Calculated Power = 1.0
# Number of Samples: 490 , Calculated Power = 1.0
# Number of Samples: 491 , Calculated Power = 1.0
# Number of Samples: 492 , Calculated Power = 1.0
# Number of Samples: 493 , Calculated Power = 1.0
# Number of Samples: 494 , Calculated Power = 1.0
# Number of Samples: 495 , Calculated Power = 1.0
# Number of Samples: 496 , Calculated Power = 1.0
# Number of Samples: 497 , Calculated Power = 1.0
# Number of Samples: 498 , Calculated Power = 1.0
# Number of Samples: 499 , Calculated Power = 1.0
# Number of Samples: 500 , Calculated Power = 1.0
# Number of Samples: 501 , Calculated Power = 1.0
# Number of Samples: 502 , Calculated Power = 1.0
# Number of Samples: 503 , Calculated Power = 1.0
# Number of Samples: 504 , Calculated Power = 1.0
# Number of Samples: 505 , Calculated Power = 1.0
# Number of Samples: 506 , Calculated Power = 1.0
# Number of Samples: 507 , Calculated Power = 1.0
# Number of Samples: 508 , Calculated Power = 1.0
# Number of Samples: 509 , Calculated Power = 1.0
# Number of Samples: 510 , Calculated Power = 1.0
# Number of Samples: 511 , Calculated Power = 1.0
# Number of Samples: 512 , Calculated Power = 1.0
# Number of Samples: 513 , Calculated Power = 1.0
# Number of Samples: 514 , Calculated Power = 1.0
# Number of Samples: 515 , Calculated Power = 1.0
# Number of Samples: 516 , Calculated Power = 1.0
# Number of Samples: 517 , Calculated Power = 1.0
# Number of Samples: 518 , Calculated Power = 1.0
# Number of Samples: 519 , Calculated Power = 1.0
# Number of Samples: 520 , Calculated Power = 1.0
# Number of Samples: 521 , Calculated Power = 1.0
# Number of Samples: 522 , Calculated Power = 1.0
# Number of Samples: 523 , Calculated Power = 1.0
# Number of Samples: 524 , Calculated Power = 1.0
# Number of Samples: 525 , Calculated Power = 1.0
# Number of Samples: 526 , Calculated Power = 1.0
# Number of Samples: 527 , Calculated Power = 1.0
# Number of Samples: 528 , Calculated Power = 1.0
# Number of Samples: 529 , Calculated Power = 1.0
# Number of Samples: 530 , Calculated Power = 1.0
# Number of Samples: 531 , Calculated Power = 1.0
# Number of Samples: 532 , Calculated Power = 1.0
# Number of Samples: 533 , Calculated Power = 1.0
# Number of Samples: 534 , Calculated Power = 1.0
# Number of Samples: 535 , Calculated Power = 1.0
# Number of Samples: 536 , Calculated Power = 1.0
# Number of Samples: 537 , Calculated Power = 1.0
# Number of Samples: 538 , Calculated Power = 1.0
# Number of Samples: 539 , Calculated Power = 1.0
# Number of Samples: 540 , Calculated Power = 1.0
# Number of Samples: 541 , Calculated Power = 1.0
# Number of Samples: 542 , Calculated Power = 1.0
# Number of Samples: 543 , Calculated Power = 1.0
# Number of Samples: 544 , Calculated Power = 1.0
# Number of Samples: 545 , Calculated Power = 1.0
# Number of Samples: 546 , Calculated Power = 1.0
# Number of Samples: 547 , Calculated Power = 1.0
# Number of Samples: 548 , Calculated Power = 1.0
# Number of Samples: 549 , Calculated Power = 1.0
# Number of Samples: 550 , Calculated Power = 1.0
# Number of Samples: 551 , Calculated Power = 1.0
# Number of Samples: 552 , Calculated Power = 1.0
# Number of Samples: 553 , Calculated Power = 1.0
# Number of Samples: 554 , Calculated Power = 1.0
# Number of Samples: 555 , Calculated Power = 1.0
# Number of Samples: 556 , Calculated Power = 1.0
# Number of Samples: 557 , Calculated Power = 1.0
# Number of Samples: 558 , Calculated Power = 1.0
# Number of Samples: 559 , Calculated Power = 1.0
# Number of Samples: 560 , Calculated Power = 1.0
# Number of Samples: 561 , Calculated Power = 1.0
# Number of Samples: 562 , Calculated Power = 1.0
# Number of Samples: 563 , Calculated Power = 1.0
# Number of Samples: 564 , Calculated Power = 1.0
# Number of Samples: 565 , Calculated Power = 1.0
# Number of Samples: 566 , Calculated Power = 1.0
# Number of Samples: 567 , Calculated Power = 1.0
# Number of Samples: 568 , Calculated Power = 1.0
# Number of Samples: 569 , Calculated Power = 1.0
# Number of Samples: 570 , Calculated Power = 1.0
# Number of Samples: 571 , Calculated Power = 1.0
# Number of Samples: 572 , Calculated Power = 1.0
# Number of Samples: 573 , Calculated Power = 1.0
# Number of Samples: 574 , Calculated Power = 1.0
# Number of Samples: 575 , Calculated Power = 1.0
# Number of Samples: 576 , Calculated Power = 1.0
# Number of Samples: 577 , Calculated Power = 1.0
# Number of Samples: 578 , Calculated Power = 1.0
# Number of Samples: 579 , Calculated Power = 1.0
# Number of Samples: 580 , Calculated Power = 1.0
# Number of Samples: 581 , Calculated Power = 1.0
# Number of Samples: 582 , Calculated Power = 1.0
# Number of Samples: 583 , Calculated Power = 1.0
# Number of Samples: 584 , Calculated Power = 1.0
# Number of Samples: 585 , Calculated Power = 1.0
# Number of Samples: 586 , Calculated Power = 1.0
# Number of Samples: 587 , Calculated Power = 1.0
# Number of Samples: 588 , Calculated Power = 1.0
# Number of Samples: 589 , Calculated Power = 1.0
# Number of Samples: 590 , Calculated Power = 1.0
# Number of Samples: 591 , Calculated Power = 1.0
# Number of Samples: 592 , Calculated Power = 1.0
# Number of Samples: 593 , Calculated Power = 1.0
# Number of Samples: 594 , Calculated Power = 1.0
# Number of Samples: 595 , Calculated Power = 1.0
# Number of Samples: 596 , Calculated Power = 1.0
# Number of Samples: 597 , Calculated Power = 1.0
# Number of Samples: 598 , Calculated Power = 1.0
# Number of Samples: 599 , Calculated Power = 1.0
# Number of Samples: 600 , Calculated Power = 1.0
# Number of Samples: 601 , Calculated Power = 1.0
# Number of Samples: 602 , Calculated Power = 1.0
# Number of Samples: 603 , Calculated Power = 1.0
# Number of Samples: 604 , Calculated Power = 1.0
# Number of Samples: 605 , Calculated Power = 1.0
# Number of Samples: 606 , Calculated Power = 1.0
# Number of Samples: 607 , Calculated Power = 1.0
# Number of Samples: 608 , Calculated Power = 1.0
# Number of Samples: 609 , Calculated Power = 1.0
# Number of Samples: 610 , Calculated Power = 1.0
# Number of Samples: 611 , Calculated Power = 1.0
# Number of Samples: 612 , Calculated Power = 1.0
# Number of Samples: 613 , Calculated Power = 1.0
# Number of Samples: 614 , Calculated Power = 1.0
# Number of Samples: 615 , Calculated Power = 1.0
# Number of Samples: 616 , Calculated Power = 1.0
# Number of Samples: 617 , Calculated Power = 1.0
# Number of Samples: 618 , Calculated Power = 1.0
# Number of Samples: 619 , Calculated Power = 1.0
# Number of Samples: 620 , Calculated Power = 1.0
# Number of Samples: 621 , Calculated Power = 1.0
# Number of Samples: 622 , Calculated Power = 1.0
# Number of Samples: 623 , Calculated Power = 1.0
# Number of Samples: 624 , Calculated Power = 1.0
# Number of Samples: 625 , Calculated Power = 1.0
# Number of Samples: 626 , Calculated Power = 1.0
# Number of Samples: 627 , Calculated Power = 1.0
# Number of Samples: 628 , Calculated Power = 1.0
# Number of Samples: 629 , Calculated Power = 1.0
# Number of Samples: 630 , Calculated Power = 1.0
# Number of Samples: 631 , Calculated Power = 1.0
# Number of Samples: 632 , Calculated Power = 1.0
# Number of Samples: 633 , Calculated Power = 1.0
# Number of Samples: 634 , Calculated Power = 1.0
# Number of Samples: 635 , Calculated Power = 1.0
# Number of Samples: 636 , Calculated Power = 1.0
# Number of Samples: 637 , Calculated Power = 1.0
# Number of Samples: 638 , Calculated Power = 1.0
# Number of Samples: 639 , Calculated Power = 1.0
# Number of Samples: 640 , Calculated Power = 1.0
# Number of Samples: 641 , Calculated Power = 1.0
# Number of Samples: 642 , Calculated Power = 1.0
# Number of Samples: 643 , Calculated Power = 1.0
# Number of Samples: 644 , Calculated Power = 1.0
# Number of Samples: 645 , Calculated Power = 1.0
# Number of Samples: 646 , Calculated Power = 1.0
# Number of Samples: 647 , Calculated Power = 1.0
# Number of Samples: 648 , Calculated Power = 1.0
# Number of Samples: 649 , Calculated Power = 1.0
# Number of Samples: 650 , Calculated Power = 1.0
# Number of Samples: 651 , Calculated Power = 1.0
# Number of Samples: 652 , Calculated Power = 1.0
# Number of Samples: 653 , Calculated Power = 1.0
# Number of Samples: 654 , Calculated Power = 1.0
# Number of Samples: 655 , Calculated Power = 1.0
# Number of Samples: 656 , Calculated Power = 1.0
# Number of Samples: 657 , Calculated Power = 1.0
# Number of Samples: 658 , Calculated Power = 1.0
# Number of Samples: 659 , Calculated Power = 1.0
# Number of Samples: 660 , Calculated Power = 1.0
# Number of Samples: 661 , Calculated Power = 1.0
# Number of Samples: 662 , Calculated Power = 1.0
# Number of Samples: 663 , Calculated Power = 1.0
# Number of Samples: 664 , Calculated Power = 1.0
# Number of Samples: 665 , Calculated Power = 1.0
# Number of Samples: 666 , Calculated Power = 1.0
# Number of Samples: 667 , Calculated Power = 1.0
# Number of Samples: 668 , Calculated Power = 1.0
# Number of Samples: 669 , Calculated Power = 1.0
# Number of Samples: 670 , Calculated Power = 1.0
# Number of Samples: 671 , Calculated Power = 1.0
# Number of Samples: 672 , Calculated Power = 1.0
# Number of Samples: 673 , Calculated Power = 1.0
# Number of Samples: 674 , Calculated Power = 1.0
# Number of Samples: 675 , Calculated Power = 1.0
# Number of Samples: 676 , Calculated Power = 1.0
# Number of Samples: 677 , Calculated Power = 1.0
# Number of Samples: 678 , Calculated Power = 1.0
# Number of Samples: 679 , Calculated Power = 1.0
# Number of Samples: 680 , Calculated Power = 1.0
# Number of Samples: 681 , Calculated Power = 1.0
# Number of Samples: 682 , Calculated Power = 1.0
# Number of Samples: 683 , Calculated Power = 1.0
# Number of Samples: 684 , Calculated Power = 1.0
# Number of Samples: 685 , Calculated Power = 1.0
# Number of Samples: 686 , Calculated Power = 1.0
# Number of Samples: 687 , Calculated Power = 1.0
# Number of Samples: 688 , Calculated Power = 1.0
# Number of Samples: 689 , Calculated Power = 1.0
# Number of Samples: 690 , Calculated Power = 1.0
# Number of Samples: 691 , Calculated Power = 1.0
# Number of Samples: 692 , Calculated Power = 1.0
# Number of Samples: 693 , Calculated Power = 1.0
# Number of Samples: 694 , Calculated Power = 1.0
# Number of Samples: 695 , Calculated Power = 1.0
# Number of Samples: 696 , Calculated Power = 1.0
# Number of Samples: 697 , Calculated Power = 1.0
# Number of Samples: 698 , Calculated Power = 1.0
# Number of Samples: 699 , Calculated Power = 1.0
# Number of Samples: 700 , Calculated Power = 1.0
# Number of Samples: 701 , Calculated Power = 1.0
# Number of Samples: 702 , Calculated Power = 1.0
# Number of Samples: 703 , Calculated Power = 1.0
# Number of Samples: 704 , Calculated Power = 1.0
# Number of Samples: 705 , Calculated Power = 1.0
# Number of Samples: 706 , Calculated Power = 1.0
# Number of Samples: 707 , Calculated Power = 1.0
# Number of Samples: 708 , Calculated Power = 1.0
# Number of Samples: 709 , Calculated Power = 1.0
# Number of Samples: 710 , Calculated Power = 1.0
# Number of Samples: 711 , Calculated Power = 1.0
# Number of Samples: 712 , Calculated Power = 1.0
# Number of Samples: 713 , Calculated Power = 1.0
# Number of Samples: 714 , Calculated Power = 1.0
# Number of Samples: 715 , Calculated Power = 1.0
# Number of Samples: 716 , Calculated Power = 1.0
# Number of Samples: 717 , Calculated Power = 1.0
# Number of Samples: 718 , Calculated Power = 1.0
# Number of Samples: 719 , Calculated Power = 1.0
# Number of Samples: 720 , Calculated Power = 1.0
# Number of Samples: 721 , Calculated Power = 1.0
# Number of Samples: 722 , Calculated Power = 1.0
# Number of Samples: 723 , Calculated Power = 1.0
# Number of Samples: 724 , Calculated Power = 1.0
# Number of Samples: 725 , Calculated Power = 1.0
# Number of Samples: 726 , Calculated Power = 1.0
# Number of Samples: 727 , Calculated Power = 1.0
# Number of Samples: 728 , Calculated Power = 1.0
# Number of Samples: 729 , Calculated Power = 1.0
# Number of Samples: 730 , Calculated Power = 1.0
# Number of Samples: 731 , Calculated Power = 1.0
# Number of Samples: 732 , Calculated Power = 1.0
# Number of Samples: 733 , Calculated Power = 1.0
# Number of Samples: 734 , Calculated Power = 1.0
# Number of Samples: 735 , Calculated Power = 1.0
# Number of Samples: 736 , Calculated Power = 1.0
# Number of Samples: 737 , Calculated Power = 1.0
# Number of Samples: 738 , Calculated Power = 1.0
# Number of Samples: 739 , Calculated Power = 1.0
# Number of Samples: 740 , Calculated Power = 1.0
# Number of Samples: 741 , Calculated Power = 1.0
# Number of Samples: 742 , Calculated Power = 1.0
# Number of Samples: 743 , Calculated Power = 1.0
# Number of Samples: 744 , Calculated Power = 1.0
# Number of Samples: 745 , Calculated Power = 1.0
# Number of Samples: 746 , Calculated Power = 1.0
# Number of Samples: 747 , Calculated Power = 1.0
# Number of Samples: 748 , Calculated Power = 1.0
# Number of Samples: 749 , Calculated Power = 1.0
# Number of Samples: 750 , Calculated Power = 1.0
# Number of Samples: 751 , Calculated Power = 1.0
# Number of Samples: 752 , Calculated Power = 1.0
# Number of Samples: 753 , Calculated Power = 1.0
# Number of Samples: 754 , Calculated Power = 1.0
# Number of Samples: 755 , Calculated Power = 1.0
# Number of Samples: 756 , Calculated Power = 1.0
# Number of Samples: 757 , Calculated Power = 1.0
# Number of Samples: 758 , Calculated Power = 1.0
# Number of Samples: 759 , Calculated Power = 1.0
# Number of Samples: 760 , Calculated Power = 1.0
# Number of Samples: 761 , Calculated Power = 1.0
# Number of Samples: 762 , Calculated Power = 1.0
# Number of Samples: 763 , Calculated Power = 1.0
# Number of Samples: 764 , Calculated Power = 1.0
# Number of Samples: 765 , Calculated Power = 1.0
# Number of Samples: 766 , Calculated Power = 1.0
# Number of Samples: 767 , Calculated Power = 1.0
# Number of Samples: 768 , Calculated Power = 1.0
# Number of Samples: 769 , Calculated Power = 1.0
# Number of Samples: 770 , Calculated Power = 1.0
# Number of Samples: 771 , Calculated Power = 1.0
# Number of Samples: 772 , Calculated Power = 1.0
# Number of Samples: 773 , Calculated Power = 1.0
# Number of Samples: 774 , Calculated Power = 1.0
# Number of Samples: 775 , Calculated Power = 1.0
# Number of Samples: 776 , Calculated Power = 1.0
# Number of Samples: 777 , Calculated Power = 1.0
# Number of Samples: 778 , Calculated Power = 1.0
# Number of Samples: 779 , Calculated Power = 1.0
# Number of Samples: 780 , Calculated Power = 1.0
# Number of Samples: 781 , Calculated Power = 1.0
# Number of Samples: 782 , Calculated Power = 1.0
# Number of Samples: 783 , Calculated Power = 1.0
# Number of Samples: 784 , Calculated Power = 1.0
# Number of Samples: 785 , Calculated Power = 1.0
# Number of Samples: 786 , Calculated Power = 1.0
# Number of Samples: 787 , Calculated Power = 1.0
# Number of Samples: 788 , Calculated Power = 1.0
# Number of Samples: 789 , Calculated Power = 1.0
# Number of Samples: 790 , Calculated Power = 1.0
# Number of Samples: 791 , Calculated Power = 1.0
# Number of Samples: 792 , Calculated Power = 1.0
# Number of Samples: 793 , Calculated Power = 1.0
# Number of Samples: 794 , Calculated Power = 1.0
# Number of Samples: 795 , Calculated Power = 1.0
# Number of Samples: 796 , Calculated Power = 1.0
# Number of Samples: 797 , Calculated Power = 1.0
# Number of Samples: 798 , Calculated Power = 1.0
# Number of Samples: 799 , Calculated Power = 1.0
# Number of Samples: 800 , Calculated Power = 1.0
# Number of Samples: 801 , Calculated Power = 1.0
# Number of Samples: 802 , Calculated Power = 1.0
# Number of Samples: 803 , Calculated Power = 1.0
# Number of Samples: 804 , Calculated Power = 1.0
# Number of Samples: 805 , Calculated Power = 1.0
# Number of Samples: 806 , Calculated Power = 1.0
# Number of Samples: 807 , Calculated Power = 1.0
# Number of Samples: 808 , Calculated Power = 1.0
# Number of Samples: 809 , Calculated Power = 1.0
# Number of Samples: 810 , Calculated Power = 1.0
# Number of Samples: 811 , Calculated Power = 1.0
# Number of Samples: 812 , Calculated Power = 1.0
# Number of Samples: 813 , Calculated Power = 1.0
# Number of Samples: 814 , Calculated Power = 1.0
# Number of Samples: 815 , Calculated Power = 1.0
# Number of Samples: 816 , Calculated Power = 1.0
# Number of Samples: 817 , Calculated Power = 1.0
# Number of Samples: 818 , Calculated Power = 1.0
# Number of Samples: 819 , Calculated Power = 1.0
# Number of Samples: 820 , Calculated Power = 1.0
# Number of Samples: 821 , Calculated Power = 1.0
# Number of Samples: 822 , Calculated Power = 1.0
# Number of Samples: 823 , Calculated Power = 1.0
# Number of Samples: 824 , Calculated Power = 1.0
# Number of Samples: 825 , Calculated Power = 1.0
# Number of Samples: 826 , Calculated Power = 1.0
# Number of Samples: 827 , Calculated Power = 1.0
# Number of Samples: 828 , Calculated Power = 1.0
# Number of Samples: 829 , Calculated Power = 1.0
# Number of Samples: 830 , Calculated Power = 1.0
# Number of Samples: 831 , Calculated Power = 1.0
# Number of Samples: 832 , Calculated Power = 1.0
# Number of Samples: 833 , Calculated Power = 1.0
# Number of Samples: 834 , Calculated Power = 1.0
# Number of Samples: 835 , Calculated Power = 1.0
# Number of Samples: 836 , Calculated Power = 1.0
# Number of Samples: 837 , Calculated Power = 1.0
# Number of Samples: 838 , Calculated Power = 1.0
# Number of Samples: 839 , Calculated Power = 1.0
# Number of Samples: 840 , Calculated Power = 1.0
# Number of Samples: 841 , Calculated Power = 1.0
# Number of Samples: 842 , Calculated Power = 1.0
# Number of Samples: 843 , Calculated Power = 1.0
# Number of Samples: 844 , Calculated Power = 1.0
# Number of Samples: 845 , Calculated Power = 1.0
# Number of Samples: 846 , Calculated Power = 1.0
# Number of Samples: 847 , Calculated Power = 1.0
# Number of Samples: 848 , Calculated Power = 1.0
# Number of Samples: 849 , Calculated Power = 1.0
# Number of Samples: 850 , Calculated Power = 1.0
# Number of Samples: 851 , Calculated Power = 1.0
# Number of Samples: 852 , Calculated Power = 1.0
# Number of Samples: 853 , Calculated Power = 1.0
# Number of Samples: 854 , Calculated Power = 1.0
# Number of Samples: 855 , Calculated Power = 1.0
# Number of Samples: 856 , Calculated Power = 1.0
# Number of Samples: 857 , Calculated Power = 1.0
# Number of Samples: 858 , Calculated Power = 1.0
# Number of Samples: 859 , Calculated Power = 1.0
# Number of Samples: 860 , Calculated Power = 1.0
# Number of Samples: 861 , Calculated Power = 1.0
# Number of Samples: 862 , Calculated Power = 1.0
# Number of Samples: 863 , Calculated Power = 1.0
# Number of Samples: 864 , Calculated Power = 1.0
# Number of Samples: 865 , Calculated Power = 1.0
# Number of Samples: 866 , Calculated Power = 1.0
# Number of Samples: 867 , Calculated Power = 1.0
# Number of Samples: 868 , Calculated Power = 1.0
# Number of Samples: 869 , Calculated Power = 1.0
# Number of Samples: 870 , Calculated Power = 1.0
# Number of Samples: 871 , Calculated Power = 1.0
# Number of Samples: 872 , Calculated Power = 1.0
# Number of Samples: 873 , Calculated Power = 1.0
# Number of Samples: 874 , Calculated Power = 1.0
# Number of Samples: 875 , Calculated Power = 1.0
# Number of Samples: 876 , Calculated Power = 1.0
# Number of Samples: 877 , Calculated Power = 1.0
# Number of Samples: 878 , Calculated Power = 1.0
# Number of Samples: 879 , Calculated Power = 1.0
# Number of Samples: 880 , Calculated Power = 1.0
# Number of Samples: 881 , Calculated Power = 1.0
# Number of Samples: 882 , Calculated Power = 1.0
# Number of Samples: 883 , Calculated Power = 1.0
# Number of Samples: 884 , Calculated Power = 1.0
# Number of Samples: 885 , Calculated Power = 1.0
# Number of Samples: 886 , Calculated Power = 1.0
# Number of Samples: 887 , Calculated Power = 1.0
# Number of Samples: 888 , Calculated Power = 1.0
# Number of Samples: 889 , Calculated Power = 1.0
# Number of Samples: 890 , Calculated Power = 1.0
# Number of Samples: 891 , Calculated Power = 1.0
# Number of Samples: 892 , Calculated Power = 1.0
# Number of Samples: 893 , Calculated Power = 1.0
# Number of Samples: 894 , Calculated Power = 1.0
# Number of Samples: 895 , Calculated Power = 1.0
# Number of Samples: 896 , Calculated Power = 1.0
# Number of Samples: 897 , Calculated Power = 1.0
# Number of Samples: 898 , Calculated Power = 1.0
# Number of Samples: 899 , Calculated Power = 1.0
# Number of Samples: 900 , Calculated Power = 1.0
# Number of Samples: 901 , Calculated Power = 1.0
# Number of Samples: 902 , Calculated Power = 1.0
# Number of Samples: 903 , Calculated Power = 1.0
# Number of Samples: 904 , Calculated Power = 1.0
# Number of Samples: 905 , Calculated Power = 1.0
# Number of Samples: 906 , Calculated Power = 1.0
# Number of Samples: 907 , Calculated Power = 1.0
# Number of Samples: 908 , Calculated Power = 1.0
# Number of Samples: 909 , Calculated Power = 1.0
# Number of Samples: 910 , Calculated Power = 1.0
# Number of Samples: 911 , Calculated Power = 1.0
# Number of Samples: 912 , Calculated Power = 1.0
# Number of Samples: 913 , Calculated Power = 1.0
# Number of Samples: 914 , Calculated Power = 1.0
# Number of Samples: 915 , Calculated Power = 1.0
# Number of Samples: 916 , Calculated Power = 1.0
# Number of Samples: 917 , Calculated Power = 1.0
# Number of Samples: 918 , Calculated Power = 1.0
# Number of Samples: 919 , Calculated Power = 1.0
# Number of Samples: 920 , Calculated Power = 1.0
# Number of Samples: 921 , Calculated Power = 1.0
# Number of Samples: 922 , Calculated Power = 1.0
# Number of Samples: 923 , Calculated Power = 1.0
# Number of Samples: 924 , Calculated Power = 1.0
# Number of Samples: 925 , Calculated Power = 1.0
# Number of Samples: 926 , Calculated Power = 1.0
# Number of Samples: 927 , Calculated Power = 1.0
# Number of Samples: 928 , Calculated Power = 1.0
# Number of Samples: 929 , Calculated Power = 1.0
# Number of Samples: 930 , Calculated Power = 1.0
# Number of Samples: 931 , Calculated Power = 1.0
# Number of Samples: 932 , Calculated Power = 1.0
# Number of Samples: 933 , Calculated Power = 1.0
# Number of Samples: 934 , Calculated Power = 1.0
# Number of Samples: 935 , Calculated Power = 1.0
# Number of Samples: 936 , Calculated Power = 1.0
# Number of Samples: 937 , Calculated Power = 1.0
# Number of Samples: 938 , Calculated Power = 1.0
# Number of Samples: 939 , Calculated Power = 1.0
# Number of Samples: 940 , Calculated Power = 1.0
# Number of Samples: 941 , Calculated Power = 1.0
# Number of Samples: 942 , Calculated Power = 1.0
# Number of Samples: 943 , Calculated Power = 1.0
# Number of Samples: 944 , Calculated Power = 1.0
# Number of Samples: 945 , Calculated Power = 1.0
# Number of Samples: 946 , Calculated Power = 1.0
# Number of Samples: 947 , Calculated Power = 1.0
# Number of Samples: 948 , Calculated Power = 1.0
# Number of Samples: 949 , Calculated Power = 1.0
# Number of Samples: 950 , Calculated Power = 1.0
# Number of Samples: 951 , Calculated Power = 1.0
# Number of Samples: 952 , Calculated Power = 1.0
# Number of Samples: 953 , Calculated Power = 1.0
# Number of Samples: 954 , Calculated Power = 1.0
# Number of Samples: 955 , Calculated Power = 1.0
# Number of Samples: 956 , Calculated Power = 1.0
# Number of Samples: 957 , Calculated Power = 1.0
# Number of Samples: 958 , Calculated Power = 1.0
# Number of Samples: 959 , Calculated Power = 1.0
# Number of Samples: 960 , Calculated Power = 1.0
# Number of Samples: 961 , Calculated Power = 1.0
# Number of Samples: 962 , Calculated Power = 1.0
# Number of Samples: 963 , Calculated Power = 1.0
# Number of Samples: 964 , Calculated Power = 1.0
# Number of Samples: 965 , Calculated Power = 1.0
# Number of Samples: 966 , Calculated Power = 1.0
# Number of Samples: 967 , Calculated Power = 1.0
# Number of Samples: 968 , Calculated Power = 1.0
# Number of Samples: 969 , Calculated Power = 1.0
# Number of Samples: 970 , Calculated Power = 1.0
# Number of Samples: 971 , Calculated Power = 1.0
# Number of Samples: 972 , Calculated Power = 1.0
# Number of Samples: 973 , Calculated Power = 1.0
# Number of Samples: 974 , Calculated Power = 1.0
# Number of Samples: 975 , Calculated Power = 1.0
# Number of Samples: 976 , Calculated Power = 1.0
# Number of Samples: 977 , Calculated Power = 1.0
# Number of Samples: 978 , Calculated Power = 1.0
# Number of Samples: 979 , Calculated Power = 1.0
# Number of Samples: 980 , Calculated Power = 1.0
# Number of Samples: 981 , Calculated Power = 1.0
# Number of Samples: 982 , Calculated Power = 1.0
# Number of Samples: 983 , Calculated Power = 1.0
# Number of Samples: 984 , Calculated Power = 1.0
# Number of Samples: 985 , Calculated Power = 1.0
# Number of Samples: 986 , Calculated Power = 1.0
# Number of Samples: 987 , Calculated Power = 1.0
# Number of Samples: 988 , Calculated Power = 1.0
# Number of Samples: 989 , Calculated Power = 1.0
# Number of Samples: 990 , Calculated Power = 1.0
# Number of Samples: 991 , Calculated Power = 1.0
# Number of Samples: 992 , Calculated Power = 1.0
# Number of Samples: 993 , Calculated Power = 1.0
# Number of Samples: 994 , Calculated Power = 1.0
# Number of Samples: 995 , Calculated Power = 1.0
# Number of Samples: 996 , Calculated Power = 1.0
# Number of Samples: 997 , Calculated Power = 1.0
# Number of Samples: 998 , Calculated Power = 1.0
# Number of Samples: 999 , Calculated Power = 1.0
# Number of Samples: 1000 , Calculated Power = 1.0
# Number of Samples: 1001 , Calculated Power = 1.0
# Number of Samples: 1002 , Calculated Power = 1.0
# Number of Samples: 1003 , Calculated Power = 1.0
# Number of Samples: 1004 , Calculated Power = 1.0
# Number of Samples: 1005 , Calculated Power = 1.0
# Number of Samples: 1006 , Calculated Power = 1.0
# Number of Samples: 1007 , Calculated Power = 1.0
# Number of Samples: 1008 , Calculated Power = 1.0
# Number of Samples: 1009 , Calculated Power = 1.0
# Number of Samples: 1010 , Calculated Power = 1.0
# Number of Samples: 1011 , Calculated Power = 1.0
# Number of Samples: 1012 , Calculated Power = 1.0
# Number of Samples: 1013 , Calculated Power = 1.0
# Number of Samples: 1014 , Calculated Power = 1.0
# Number of Samples: 1015 , Calculated Power = 1.0
# Number of Samples: 1016 , Calculated Power = 1.0
# Number of Samples: 1017 , Calculated Power = 1.0
# Number of Samples: 1018 , Calculated Power = 1.0
# Number of Samples: 1019 , Calculated Power = 1.0
# Number of Samples: 1020 , Calculated Power = 1.0
# Number of Samples: 1021 , Calculated Power = 1.0
# Number of Samples: 1022 , Calculated Power = 1.0
# Number of Samples: 1023 , Calculated Power = 1.0
# Number of Samples: 1024 , Calculated Power = 1.0
# Number of Samples: 1025 , Calculated Power = 1.0
# Number of Samples: 1026 , Calculated Power = 1.0
# Number of Samples: 1027 , Calculated Power = 1.0
# Number of Samples: 1028 , Calculated Power = 1.0
# Number of Samples: 1029 , Calculated Power = 1.0
# Number of Samples: 1030 , Calculated Power = 1.0
# Number of Samples: 1031 , Calculated Power = 1.0
# Number of Samples: 1032 , Calculated Power = 1.0
# Number of Samples: 1033 , Calculated Power = 1.0
# Number of Samples: 1034 , Calculated Power = 1.0
# Number of Samples: 1035 , Calculated Power = 1.0
# Number of Samples: 1036 , Calculated Power = 1.0
# Number of Samples: 1037 , Calculated Power = 1.0
# Number of Samples: 1038 , Calculated Power = 1.0
# Number of Samples: 1039 , Calculated Power = 1.0
# Number of Samples: 1040 , Calculated Power = 1.0
# Number of Samples: 1041 , Calculated Power = 1.0
# Number of Samples: 1042 , Calculated Power = 1.0
# Number of Samples: 1043 , Calculated Power = 1.0
# Number of Samples: 1044 , Calculated Power = 1.0
# Number of Samples: 1045 , Calculated Power = 1.0
# Number of Samples: 1046 , Calculated Power = 1.0
# Number of Samples: 1047 , Calculated Power = 1.0
# Number of Samples: 1048 , Calculated Power = 1.0
# Number of Samples: 1049 , Calculated Power = 1.0
# Number of Samples: 1050 , Calculated Power = 1.0
# Number of Samples: 1051 , Calculated Power = 1.0
# Number of Samples: 1052 , Calculated Power = 1.0
# Number of Samples: 1053 , Calculated Power = 1.0
# Number of Samples: 1054 , Calculated Power = 1.0
# Number of Samples: 1055 , Calculated Power = 1.0
# Number of Samples: 1056 , Calculated Power = 1.0
# Number of Samples: 1057 , Calculated Power = 1.0
# Number of Samples: 1058 , Calculated Power = 1.0
# Number of Samples: 1059 , Calculated Power = 1.0
# Number of Samples: 1060 , Calculated Power = 1.0
# Number of Samples: 1061 , Calculated Power = 1.0
# Number of Samples: 1062 , Calculated Power = 1.0
# Number of Samples: 1063 , Calculated Power = 1.0
# Number of Samples: 1064 , Calculated Power = 1.0
# Number of Samples: 1065 , Calculated Power = 1.0
# Number of Samples: 1066 , Calculated Power = 1.0
# Number of Samples: 1067 , Calculated Power = 1.0
# Number of Samples: 1068 , Calculated Power = 1.0
# Number of Samples: 1069 , Calculated Power = 1.0
# Number of Samples: 1070 , Calculated Power = 1.0
# Number of Samples: 1071 , Calculated Power = 1.0
# Number of Samples: 1072 , Calculated Power = 1.0
# Number of Samples: 1073 , Calculated Power = 1.0
# Number of Samples: 1074 , Calculated Power = 1.0
# Number of Samples: 1075 , Calculated Power = 1.0
# Number of Samples: 1076 , Calculated Power = 1.0
# Number of Samples: 1077 , Calculated Power = 1.0
# Number of Samples: 1078 , Calculated Power = 1.0
# Number of Samples: 1079 , Calculated Power = 1.0
# Number of Samples: 1080 , Calculated Power = 1.0
# Number of Samples: 1081 , Calculated Power = 1.0
# Number of Samples: 1082 , Calculated Power = 1.0
# Number of Samples: 1083 , Calculated Power = 1.0

# %% [markdown]
# You can also plot the calculated power against sample size to visually inspect the effect of increasing sample size.

# %%
# Plot a sample size X Power line graph
plt.figure(figsize=(10,5))
plt.title('Power vs. Sample Size')
plt.xlabel('Sample Size')
plt.ylabel('Power')

ans = power_sample
df = pd.DataFrame(ans, index=None)
plt.plot(df[0], df[1])

plt.show()

# %% [markdown]
# This output indicates that in order to get the required power (80%) to detect a difference of 0.17, you would need a considerably higher number of patients.

# %% [markdown]
# ## BONUS: Investigating the Relationship Between Power, Sample Size and Effect Size
#
# You've seen how to calculate power given alpha, sample size, and effect size. To further investigate this relationship, it is interesting to plot the relationship between power and sample size for various effect sizes.
#
# To do this, run multiple simulations for varying parameters. Then store the parameters and plot the resulting dataset. Specifically:
#
# 1. Use a value of $\alpha$ = 0.05 for all of your simulations
# 2. Use the following effect sizes: [0.01, 0.05, 0.1, 0.15, 0.2, 0.3, 0.5]
# 3. Use the sample sizes from 10 to 500
# 4. For each effect size sample size combination, calculate the accompanying power
# 5. Plot a line graph of the power vs sample size relationship. You should have 7 plots; one for each of the effect sizes listed above. All 7 plots can be on the same graph but should be labeled appropriately. Plot the power on the y-axis and sample size on the x-axis.

# %%
def power_curve(min_sample_size = 10, max_sample_size=500, n_sim = 1000, control_mean = 0,
                control_sd = 0.21, experimental_mean = 0.17, experimental_sd = 0.21):
    p = (np.empty(n_sim))
    p.fill(np.nan)

    # keep iterating until desired power is obtained

    power_sample = []
    for sample_size in range(min_sample_size, max_sample_size, 5):

        data = np.empty([n_sim, sample_size, 2])
        data.fill(np.nan)

        # For control group 
        data[:,:,0] = np.random.normal(loc=control_mean, scale=control_sd, size=[n_sim, sample_size])

        # For experimental group
        data[:,:,1] = np.random.normal(loc=experimental_mean, scale=experimental_sd, size=[n_sim, sample_size])            

        result = stats.ttest_ind(data[:, :, 0],data[:, :, 1],axis=1)

        p_vals = result[1]

        #Since you know that all simulations are from a different distribution \
        #all those that rejected the null-hypothesis are valid
        null_rejected = np.sum(p_vals < 0.05) / n_sim

        power_sample.append(null_rejected)

    return power_sample
cols = {}

for exp_mean in [0.01, 0.05, 0.1, 0.15, 0.2, 0.3, 0.5]:
    col = power_curve(experimental_mean=exp_mean)
    cols[exp_mean] = col
df = pd.DataFrame.from_dict(cols)
df.index = list(range(10,500,5))
df.plot(figsize=(10,10))
plt.legend(title='Effect Size',loc=(1,0.8))
plt.title('Power Curves for Various Sample Sizes and Effect Sizes with Alpha=0.05')
plt.xlabel('Sample Size')
plt.ylabel('Power');

# %% [markdown]
# ## Summary
#
# In this lesson, you gained further practice with "statistical power" and how it can be used to analyze experimental design. You ran a simulation to determine the sample size that would provide a given value of power (for a given alpha and effect size). Running simulations like this, as well as further investigations regarding required sample sizes for higher power thresholds or smaller effect sizes, is critical in designing meaningful experiments where one can be confident in the subsequent conclusions drawn.
